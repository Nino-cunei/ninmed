# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import collections
import pickle
import gzip

from tf.app import use

# %%
A = use("Nino-cunei/ninmed:clone", checkout="clone", hoist=globals())
# Out:
# <b title="local github">TF-app:</b> <span title="repo clone offline under ~/github">~/github/Nino-cunei/ninmed/app</span>
# <b title="local github">data:</b> <span title="repo clone offline under ~/github">~/github/Nino-cunei/ninmed/tf/0.3</span>
# This is Text-Fabric 9.2.5
# Api reference : https://annotation.github.io/text-fabric/tf/cheatsheet.html
#
# 48 features found and 0 ignored
# <b>Text-Fabric:</b> <a target="_blank" href="https://annotation.github.io/text-fabric/tf/cheatsheet.html" title="text-fabric-api">Text-Fabric API 9.2.5</a>, <a target="_blank" href="https://github.com/Nino-cunei/ninmed/blob/master/app" title="Nino-cunei/ninmed TF-app">Nino-cunei/ninmed/app  v3</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/tf/about/searchusage.html" title="Search Templates Introduction and Reference">Search Reference</a><br><b>Data:</b> <a target="_blank" href="https://github.com/Nino-cunei/ninmed/blob/master/docs/about.md" title="provenance of Nineveh Medical Encyclopedia 800 BCE: Cuneiform tablets">NINMED</a>, <a target="_blank" href="https://nbviewer.jupyter.org/github/Nino-cunei/tfFromAtf/blob/master/programs/mapReadings.ipynb" title="mapping from readings to UNICODE">Character table</a>, <a target="_blank" href="https://github.com/Nino-cunei/ninmed/blob/master/docs/transcription.md" title="NINMED feature documentation">Feature docs</a><br><b>Features:</b><br>
# <details><summary><b>Nineveh Medical Encyclopedia 800 BCE: Cuneiform tablets</b></summary>
#     <div class="fcorpus">
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/Nino-cunei/ninmed/blob/master/docs/transcription.md" title="~/github/Nino-cunei/ninmed/tf/0.3/after.tf">after</a>
# </div>
# <div class="fmono">str</div>
# <details>
#     <summary>what comes after a sign or word (- or space)</summary>
#     <div class="fmeta">
#
# <div class="fmetarow">
#     <div class="fmetakey">converters:</div>
#     <div>Cale Johnson, Dirk Roorda</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">dateWritten:</div>
#     <div>2022-02-10T09:59:19Z</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">editor:</div>
#     <div>Cale Johnson et al.</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">name:</div>
#     <div>NinMed Medical Texts from Nineveh</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">project:</div>
#     <div>BabMed</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">writtenBy:</div>
#     <div>Text-Fabric</div>
# </div>
#
#         </div>
#     </details>
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/Nino-cunei/ninmed/blob/master/docs/transcription.md" title="~/github/Nino-cunei/ninmed/tf/0.3/atf.tf">atf</a>
# </div>
# <div class="fmono">str</div>
# <details>
#     <summary>full atf of a sign</summary>
#     <div class="fmeta">
#
# <div class="fmetarow">
#     <div class="fmetakey">converters:</div>
#     <div>Cale Johnson, Dirk Roorda</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">dateWritten:</div>
#     <div>2022-02-10T09:59:19Z</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">editor:</div>
#     <div>Cale Johnson et al.</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">name:</div>
#     <div>NinMed Medical Texts from Nineveh</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">project:</div>
#     <div>BabMed</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">writtenBy:</div>
#     <div>Text-Fabric</div>
# </div>
#
#         </div>
#     </details>
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/Nino-cunei/ninmed/blob/master/docs/transcription.md" title="~/github/Nino-cunei/ninmed/tf/0.3/atfpost.tf">atfpost</a>
# </div>
# <div class="fmono">str</div>
# <details>
#     <summary>cluster characters that follow a sign or word</summary>
#     <div class="fmeta">
#
# <div class="fmetarow">
#     <div class="fmetakey">converters:</div>
#     <div>Cale Johnson, Dirk Roorda</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">dateWritten:</div>
#     <div>2022-02-10T09:59:19Z</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">editor:</div>
#     <div>Cale Johnson et al.</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">name:</div>
#     <div>NinMed Medical Texts from Nineveh</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">project:</div>
#     <div>BabMed</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">writtenBy:</div>
#     <div>Text-Fabric</div>
# </div>
#
#         </div>
#     </details>
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/Nino-cunei/ninmed/blob/master/docs/transcription.md" title="~/github/Nino-cunei/ninmed/tf/0.3/atfpre.tf">atfpre</a>
# </div>
# <div class="fmono">str</div>
# <details>
#     <summary>cluster characters that precede a sign or word</summary>
#     <div class="fmeta">
#
# <div class="fmetarow">
#     <div class="fmetakey">converters:</div>
#     <div>Cale Johnson, Dirk Roorda</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">dateWritten:</div>
#     <div>2022-02-10T09:59:19Z</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">editor:</div>
#     <div>Cale Johnson et al.</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">name:</div>
#     <div>NinMed Medical Texts from Nineveh</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">project:</div>
#     <div>BabMed</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">writtenBy:</div>
#     <div>Text-Fabric</div>
# </div>
#
#         </div>
#     </details>
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/Nino-cunei/ninmed/blob/master/docs/transcription.md" title="~/github/Nino-cunei/ninmed/tf/0.3/col.tf">col</a>
# </div>
# <div class="fmono">int</div>
# <details>
#     <summary>ATF column number</summary>
#     <div class="fmeta">
#
# <div class="fmetarow">
#     <div class="fmetakey">converters:</div>
#     <div>Cale Johnson, Dirk Roorda</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">dateWritten:</div>
#     <div>2022-02-10T09:59:19Z</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">editor:</div>
#     <div>Cale Johnson et al.</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">name:</div>
#     <div>NinMed Medical Texts from Nineveh</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">project:</div>
#     <div>BabMed</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">writtenBy:</div>
#     <div>Text-Fabric</div>
# </div>
#
#         </div>
#     </details>
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/Nino-cunei/ninmed/blob/master/docs/transcription.md" title="~/github/Nino-cunei/ninmed/tf/0.3/collated.tf">collated</a>
# </div>
# <div class="fmono">int</div>
# <details>
#     <summary>whether a sign is collated (*)</summary>
#     <div class="fmeta">
#
# <div class="fmetarow">
#     <div class="fmetakey">converters:</div>
#     <div>Cale Johnson, Dirk Roorda</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">dateWritten:</div>
#     <div>2022-02-10T09:59:19Z</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">editor:</div>
#     <div>Cale Johnson et al.</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">name:</div>
#     <div>NinMed Medical Texts from Nineveh</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">project:</div>
#     <div>BabMed</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">writtenBy:</div>
#     <div>Text-Fabric</div>
# </div>
#
#         </div>
#     </details>
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/Nino-cunei/ninmed/blob/master/docs/transcription.md" title="~/github/Nino-cunei/ninmed/tf/0.3/collection.tf">collection</a>
# </div>
# <div class="fmono">str</div>
# <details>
#     <summary>collection name from metadata field "collection"</summary>
#     <div class="fmeta">
#
# <div class="fmetarow">
#     <div class="fmetakey">converters:</div>
#     <div>Cale Johnson, Dirk Roorda</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">dateWritten:</div>
#     <div>2022-02-10T09:59:19Z</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">editor:</div>
#     <div>Cale Johnson et al.</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">name:</
# <style>tr.tf.ltr, td.tf.ltr, th.tf.ltr { text-align: left ! important;}
# tr.tf.rtl, td.tf.rtl, th.tf.rtl { text-align: right ! important;}
# @font-face {
#   font-family: "Gentium Plus";
#   src: local('Gentium Plus'), local('GentiumPlus'),
#     url('/server/static/fonts/GentiumPlus-R.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/GentiumPlus-R.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Ezra SIL";
#   src: local('Ezra SIL'), local('EzraSIL'),
#     url('/server/static/fonts/SILEOT.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SILEOT.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "SBL Hebrew";
#   src: local('SBL Hebrew'), local('SBLHebrew'),
#     url('/server/static/fonts/SBL_Hbrw.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SBL_Hbrw.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Estrangelo Edessa";
#   src: local('Estrangelo Edessa'), local('EstrangeloEdessa');
#     url('/server/static/fonts/SyrCOMEdessa.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SyrCOMEdessa.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: AmiriQuran;
#   font-style: normal;
#   font-weight: 400;
#   src: local('Amiri Quran'), local('AmiriQuran'),
#     url('/server/static/fonts/AmiriQuran.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/AmiriQuran.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: AmiriQuranColored;
#   font-style: normal;
#   font-weight: 400;
#   src: local('Amiri Quran Colored'), local('AmiriQuranColored'),
#     url('/server/static/fonts/AmiriQuranColored.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/AmiriQuranColored.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Santakku";
#   src: local('Santakku'),
#     url('/server/static/fonts/Santakku.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/Santakku.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "SantakkuM";
#   src: local('SantakkuM'),
#     url('/server/static/fonts/SantakkuM.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SantakkuM.woff?raw=true') format('woff');
# }
# /* bypassing some classical notebook settings */
# div#notebook {
#   line-height: unset;
# }
# /* neutral text */
# .txtn,.txtn a:visited,.txtn a:link {
#     font-family: sans-serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* transcription text */
# .txtt,.txtt a:visited,.txtt a:link {
#     font-family: monospace;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* source text */
# .txto,.txto a:visited,.txto a:link {
#     font-family: serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* phonetic text */
# .txtp,.txtp a:visited,.txtp a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* original script text */
# .txtu,.txtu a:visited,.txtu a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* hebrew */
# .txtu.hbo,.lex.hbo {
#     font-family: "Ezra SIL", "SBL Hebrew", sans-serif;
#     font-size: large;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* syriac */
# .txtu.syc,.lex.syc {
#     font-family: "Estrangelo Edessa", sans-serif;
#     font-size: medium;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* neo aramaic */
# .txtu.cld,.lex.cld {
#     font-family: "CharisSIL-R", sans-serif;
#     font-size: medium;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# /* standard arabic */
# .txtu.ara,.lex.ara {
#     font-family: "AmiriQuran", sans-serif;
#     font-size: large;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* cuneiform */
# .txtu.akk,.lex.akk {
#     font-family: Santakku, sans-serif;
#     font-size: large;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# /* greek */
# .txtu.grc,.lex.grc a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# a:hover {
#     text-decoration: underline | important;
#     color: #0000ff | important;
# }
# .ltr {
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .rtl {
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# .ubd {
#     unicode-bidi: embed;
# }
# .col {
#    display: inline-block;
# }
# .features {
#     font-family: monospace;
#     font-size: medium;
#     font-weight: bold;
#     color: var(--features);
#     display: flex;
#     flex-flow: column nowrap;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     padding: 2px;
#     margin: 2px;
#     direction: ltr;
#     unicode-bidi: embed;
#     border: var(--meta-width) solid var(--meta-color);
#     border-radius: var(--meta-width);
# }
# .features div,.features span {
#     padding: 0;
#     margin: -2px 0;
# }
# .features .f {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: normal;
#     color: #5555bb;
# }
# .features .xft {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: medium;
#   margin: 2px 0px;
# }
# .features .xft .f {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: small;
#   font-weight: normal;
# }
# .tfsechead {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: var(--tfsechead);
#     unicode-bidi: embed;
#     text-align: start;
# }
# .structure {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: var(--structure);
#     unicode-bidi: embed;
#     text-align: start;
# }
# .comments {
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
# }
# .nd, a:link.nd {
#     font-family: sans-serif;
#     font-size: small;
#     color: var(--node);
#     vertical-align: super;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .lex {
#   color: var(--lex-color);;
# }
# .children,.children.ltr {
#     display: flex;
#     border: 0;
#     background-color: #ffffff;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
# }
# .children.stretch {
#     align-items: stretch;
# }
# .children.hor {
#     flex-flow: row nowrap;
# }
# .children.hor.wrap {
#     flex-flow: row wrap;
# }
# .children.ver {
#     flex-flow: column nowrap;
# }
# .children.ver.wrap {
#     flex-flow: column wrap;
# }
# .contnr {
#     width: fit-content;
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
#     background: #ffffff none repeat scroll 0 0;
#     padding:  10px 2px 2px 2px;
#     margin: 16px 2px 2px 2px;
#     border-style: solid;
#     font-size: small;
# }
# .contnr.trm {
#     background-attachment: local;
# }
# .contnr.cnul {
#     padding:  0;
#     margin: 0;
#     border-style: solid;
#     font-size: xx-small;
# }
# .contnr.cnul,.lbl.cnul {
#     border-color: var(--border-color-nul);
#     border-width: var(--border-width-nul);
#     border-radius: var(--border-width-nul);
# }
# .contnr.c0,.lbl.c0 {
#     border-color: var(--border-color0);
#     border-width: var(--border-width0);
#     border-radius: var(--border-width0);
# }
# .contnr.c1,.lbl.c1 {
#     border-color: var(--border-color1);
#     border-width: var(--border-width1);
#     border-radius: var(--border-width1);
# }
# .contnr.c2,.lbl.c2 {
#     border-color: var(--border-color2);
#     border-width: var(--border-width2);
#     border-radius: var(--border-width2);
# }
# .contnr.c3,.lbl.c3 {
#     border-color: var(--border-
# <script>
# const copyChar = (el, c) => {
#     for (const el of document.getElementsByClassName('ccon')) {
#         el.className = 'ccoff'
#     }
#     el.className = 'ccon'
#     navigator.clipboard.writeText(String.fromCharCode(c))
# }
# </script>
# <div><b>Text-Fabric API:</b> names <a target="_blank" href="https://annotation.github.io/text-fabric/tf/cheatsheet.html" title="doc">N F E L T S C TF</a> directly usable</div><hr>

# %% [markdown]
# # Parallels
#
# We make edges between similar lines.
#
# When are lines similar?
#
# If a certain distance metric is above a certain threshold.
#
# We choose this metric:
#
# * we reduce a line to the set of readings and graphemes in it, excluding unknown signs and ellipses.
# * the similarity between two lines is the length of the intersection divided by the length of the union of their sets times 100.

# %% [markdown]
# # Preparation
#
# We pre-compute all sets for all lines.

# %%
READABLE_TYPES = {"reading", "grapheme"}


def makeSet(ln):
    lineSet = set()
    for s in L.d(ln, otype="sign"):
        if F.type.v(s) in READABLE_TYPES:
            r = F.reading.v(s)
            if r:
                lineSet.add(r)
            g = F.grapheme.v(s)
            if g:
                lineSet.add(g)
    return lineSet

# %%
lines = {}

for ln in F.otype.s("line"):
    lineSet = makeSet(ln)
    if lineSet:
        lines[ln] = lineSet

nLines = len(lines)
print(f"{nLines} lines")
# Out:
# 2925 lines

# %% [markdown]
# # Measure

# %%
def sim(lSet, mSet):
    return int(round(100 * len(lSet & mSet) / len(lSet | mSet)))

# %% [markdown]
# # Compute all similarities
#
# We are going to perform several hundreds of millions of comparisons, each of which is more than an elemetary operation.
#
# Let's measure time.

# %%
THRESHOLD = 80


def computeSim(limit=None):
    similarity = {}

    lineNodes = sorted(lines.keys())
    nLines = len(lineNodes)

    nComparisons = nLines * (nLines - 1) // 2

    print(f"{nComparisons} comparisons to make")
    chunkSize = nComparisons // 100

    co = 0
    b = 0
    si = 0
    p = 0

    A.indent(reset=True)

    stop = False
    for i in range(nLines):
        nodeI = lineNodes[i]
        lineI = lines[nodeI]
        for j in range(i + 1, nLines):
            nodeJ = lineNodes[j]
            lineJ = lines[nodeJ]
            s = sim(lineI, lineJ)
            co += 1
            b += 1
            if b == chunkSize:
                p += 1
                A.info(f"{p:>3}% - {co:>12} comparisons and {si:>10} similarities")
                b = 0
                if limit is not None and p >= limit:
                    stop = True
                    break

            if s < THRESHOLD:
                continue
            similarity[(nodeI, nodeJ)] = sim(lineI, lineJ)
            si += 1
        if stop:
            break

    A.info(f"{p:>3}% - {co:>12} comparisons and {si:>10} similarities")
    return similarity

# %% [markdown]
# We are going to run it to 2% first and do some checks then.

# %%
similarity = computeSim(limit=2)
# Out:
# 4276350 comparisons to make
#   0.08s   1% -        42763 comparisons and          6 similarities
#   0.14s   2% -        85526 comparisons and         10 similarities
#   0.14s   2% -        85526 comparisons and         10 similarities

# %% [markdown]
# We check the sanity of the results.

# %%
print(min(similarity.values()))
print(max(similarity.values()))
# Out:
# 80
# 100

# %%
eq = [x for x in similarity.items() if x[1] >= 100]
neq = [x for x in similarity.items() if x[1] <= 90]

# %%
print(len(eq))
print(len(neq))
# Out:
# 8
# 2

# %%
print(eq[0])
print(neq[0])
# Out:
# ((59315, 59324), 100)
# ((59319, 61949), 80)

# %%
A.plain(eq[0][0][0])
A.plain(eq[0][0][1])
# Out:
# <div class=""><span class="tfsechead "><span class="ltr"><a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P285136" title="Show this document on CDLI" sec="P285136 obverse:2'">P285136 obverse:2'</a></span></span>  <span class="txtt">5 </span><span class="txtt">KA#.</span><span class="txtt">INIM.</span><span class="txtt">MA </span><span class="txtt">[x </span><span class="txtt">x </span><span class="txtt">x </span><span class="txtt">x]
# </span></div>
# <div class=""><span class="tfsechead "><span class="ltr"><a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P285136" title="Show this document on CDLI" sec="P285136 obverse:11'">P285136 obverse:11'</a></span></span>  <span class="txtt">2 </span><span class="txtt">KA.</span><span class="txtt">INIM.</span><span class="txtt">MA </span><span class="txtt">[x </span><span class="txtt">x </span><span class="txtt">x </span><span class="txtt">x </span><span class="txtt">x </span><span class="txtt">x]
# </span></div>

# %%
A.plain(neq[0][0][0])
A.plain(neq[0][0][1])
# Out:
# <div class=""><span class="tfsechead "><span class="ltr"><a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P285136" title="Show this document on CDLI" sec="P285136 obverse:6'">P285136 obverse:6'</a></span></span>  <span class="txtt">EN₂ </span><span class="txtt">ma-</span><span class="txtt">mit </span><span class="txtt">GIM </span><span class="txtt">šar-</span><span class="txtt">ra-</span><span class="txtt">&lt;qi₂> </span><span class="txtt">ina </span><span class="txtt">KA₂ </span><span class="txtt">pil-</span><span class="txtt">ši </span><span class="txtt">un </span><span class="txtt">gi </span><span class="txtt">ha </span><span class="txtt">ba# </span><span class="txtt">[x </span><span class="txtt">x </span><span class="txtt">x </span><span class="txtt">x </span><span class="txtt">x </span><span class="txtt">x </span><span class="txtt">x </span><span class="txtt">x </span><span class="txtt">x </span><span class="txtt">x </span><span class="txtt">x </span><span class="txtt">x]
# </span></div>
# <div class=""><span class="tfsechead "><span class="ltr"><a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P396392" title="Show this document on CDLI" sec="P396392 reverse:1:71'">P396392 reverse:1:71'</a></span></span>  <span class="txtt">[EN₂ </span><span class="txtt">ma]-</span><span class="txtt">mit </span><span class="txtt">GIM </span><span class="txtt">šar-</span><span class="txtt">ra-</span><span class="txtt">qi₂ </span><span class="txtt">ina </span><span class="txtt">KA₂ </span><span class="txtt">pil-</span><span class="txtt">ši# </span><span class="txtt">[un? </span><span class="txtt">...]
# </span></div>

# %% [markdown]
# Looks good.
#
# Now the whole computation.
#
# But if we have done this before, and nothing has changed, we load previous results from disk.
#
# If we do not find previous results, we compute them and save the results to disk.

# %%
PARA_DIR = f"{A.tempDir}/parallels"


def writeResults(data, location, name):
    if not os.path.exists(location):
        os.makedirs(location, exist_ok=True)
    path = f"{location}/{name}"
    with gzip.open(path, "wb") as f:
        pickle.dump(data, f)
    print(f"Data written to {path}")


def readResults(location, name):
    path = f"{location}/{name}"
    if not os.path.exists(path):
        print(f"File not found: {path}")
        return None
    with gzip.open(path, "rb") as f:
        data = pickle.load(f)
    print(f"Data read from {path}")
    return data

# %%
similarity = readResults(PARA_DIR, f"sim-{A.version}.zip")
if not similarity:
    similarity = computeSim()
    writeResults(similarity, PARA_DIR, f"sim-{A.version}.zip")
# Out:
# File not found: /Users/werk/github/Nino-cunei/ninmed/_temp/parallels/sim-0.3.zip
# 4276350 comparisons to make
#   0.07s   1% -        42763 comparisons and          6 similarities
#   0.13s   2% -        85526 comparisons and         10 similarities
#   0.19s   3% -       128289 comparisons and         10 similarities
#   0.25s   4% -       171052 comparisons and         14 similarities
#   0.31s   5% -       213815 comparisons and         17 similarities
#   0.37s   6% -       256578 comparisons and         17 similarities
#   0.47s   7% -       299341 comparisons and         20 similarities
#   0.54s   8% -       342104 comparisons and         21 similarities
#   0.62s   9% -       384867 comparisons and         22 similarities
#   0.69s  10% -       427630 comparisons and         24 similarities
#   0.76s  11% -       470393 comparisons and         24 similarities
#   0.83s  12% -       513156 comparisons and         28 similarities
#   0.90s  13% -       555919 comparisons and         31 similarities
#   0.97s  14% -       598682 comparisons and         32 similarities
#   1.03s  15% -       641445 comparisons and         36 similarities
#   1.11s  16% -       684208 comparisons and         36 similarities
#   1.18s  17% -       726971 comparisons and         38 similarities
#   1.24s  18% -       769734 comparisons and         47 similarities
#   1.31s  19% -       812497 comparisons and         50 similarities
#   1.37s  20% -       855260 comparisons and         53 similarities
#   1.44s  21% -       898023 comparisons and         91 similarities
#   1.52s  22% -       940786 comparisons and         91 similarities
#   1.59s  23% -       983549 comparisons and         91 similarities
#   1.67s  24% -      1026312 comparisons and         92 similarities
#   1.74s  25% -      1069075 comparisons and         92 similarities
#   1.83s  26% -      1111838 comparisons and         92 similarities
#   1.90s  27% -      1154601 comparisons and         92 similarities
#   1.98s  28% -      1197364 comparisons and         94 similarities
#   2.05s  29% -      1240127 comparisons and         96 similarities
#   2.13s  30% -      1282890 comparisons and         96 similarities
#   2.21s  31% -      1325653 comparisons and         96 similarities
#   2.29s  32% -      1368416 comparisons and         96 similarities
#   2.37s  33% -      1411179 comparisons and         97 similarities
#   2.44s  34% -      1453942 comparisons and         98 similarities
#   2.52s  35% -      1496705 comparisons and        143 similarities
#   2.60s  36% -      1539468 comparisons and        148 similarities
#   2.66s  37% -      1582231 comparisons and        155 similarities
#   2.73s  38% -      1624994 comparisons and        157 similarities
#   2.81s  39% -      1667757 comparisons and        159 similarities
#   2.88s  40% -      1710520 comparisons and        160 similarities
#   2.96s  41% -      1753283 comparisons and        166 similarities
#   3.04s  42% -      1796046 comparisons and        171 similarities
#   3.13s  43% -      1838809 comparisons and        171 similarities
#   3.21s  44% -      1881572 comparisons and        171 similarities
#   3.29s  45% -      1924335 comparisons and        171 similarities
#   3.37s  46% -      1967098 comparisons and        171 similarities
#   3.45s  47% -      2009861 comparisons and        171 similarities
#   3.52s  48% -      2052624 comparisons and        196 similarities
#   3.60s  49% -      2095387 comparisons and        196 similarities
#   3.67s  50% -      2138150 comparisons and        201 similarities
#   3.75s  51% -      2180913 comparisons and        201 similarities
#   3.82s  52% -      2223676 comparisons and        203 similarities
#   3.90s  53% -      2266439 comparisons and        203 similarities
#   3.98s  54% -      2309202 comparisons and        203 similarities
#   4.06s  55% -      2351965 comparisons and        204 similarities
#   4.14s  56% -      2394728 comparisons and        204 similarities
#   4.22s  57% -      2437491 comparisons and        204 similarities
#   4.28s  58% -      2480254 comparisons and        206 similarities
#   4.36s  59% -      2523017 comparisons and        239 similarities
#   4.43s  60% -      2565780 comparisons and        239 similarities
#   4.51s  61% -      2608543 comparisons and        243 similarities
#   4.58s  62% -      2651306 comparisons and        245 similarities
#   4.66s  63% -      2694069 comparisons and        246 similarities
#   4.74s  64% -      2736832 comparisons and        253 similarities
#   4.82s  65% -      2779595 comparisons and        259 similarities
#   4.90s  66% -      2822358 comparisons and        261 similarities
#   4.98s  67% -      2865121 comparisons and        261 similarities
#   5.05s  68% -      2907884 comparisons and        269 similarities
#   5.10s  69% -      2950647 comparisons and        302 similarities
#   5.17s  70% -      2993410 comparisons and        306 similarities
#   5.24s  71% -      3036173 comparisons and        306 similarities
#   5.30s  72% -      3078936 comparisons and        309 similarities
#   5.38s  73% -      3121699 comparisons and        309 similarities
#   5.45s  74% -      3164462 comparisons and        338 similarities
#   5.52s  75% -      3207225 comparisons and        350 similarities
#   5.60s  76% -      3249988 comparisons and        350 similarities
#   5.67s  77% -      3292751 comparisons and        352 similarities
#   5.75s  78% -      3335514 comparisons and        354 similarities
#   5.83s  79% -      3378277 comparisons and        359 similarities
#   5.91s  80% -      3421040 comparisons and        390 similarities
#   6.00s  81% -      3463803 comparisons and        457 similarities
#   6.07s  82% -      3506566 comparisons and        486 similarities
#   6.15s  83% -      3549329 comparisons and        500 similarities
#   6.22s  84% -      3592092 comparisons and        504 similarities
#   6.30s  85% -      3634855 comparisons and        518 similarities
#   6.38s  86% -      3677618 comparisons and        528 similarities
#   6.46s  87% -      3720381 comparisons and        529 similarities
#   6.54s  88% -      3763144 comparisons and        529 similarities
#   6.61s  89% -      3805907 comparisons and        539 similarities
#   6.69s  90% -      3848670 comparisons and        546 similarities
#   6.77s  91% -      3891433 comparisons and        572 similarities
#   6.84s  92% -      3934196 comparisons and        587 similarities
#   6.92s  93% -      3976959 comparisons and        605 similarities
#   7.00s  94% -      4019722 comparisons and        605 similarities
#   7.08s  95% -      4062485 comparisons and        605 similarities
#   7.17s  96% -      4105248 comparisons and        606 similarities
#   7.25s  97% -      4148011 comparisons and        621 similarities
#   7.33s  98% -      4190774 comparisons and        621 similarities
#   7.41s  99% -      4233537 comparisons and        625 similarities
#   7.50s 100% -      4276300 comparisons and        634 similarities
#   7.50s 100% -      4276350 comparisons and        634 similarities
# Data written to /Users/werk/github/Nino-cunei/ninmed/_temp/parallels/sim-0.3.zip

# %%
len(similarity)
# Out:
# 634

# %% [markdown]
# Let's find out which lines have the most correspondences.

# %%
parallels = {}

for (ln, m) in similarity:
    parallels.setdefault(ln, set()).add(m)
    parallels.setdefault(m, set()).add(ln)

print(f"{len(parallels)} out of {nLines} lines have at least one similar line")
# Out:
# 502 out of 2925 lines have at least one similar line

# %%
rankedParallels = sorted(
    parallels.items(),
    key=lambda x: (-len(x[1]), x[0]),
)

# %%
for (ln, paras) in rankedParallels[0:10]:
    print(f"{len(paras):>4} siblings of {ln} = {T.text(ln).rstrip()}")
# Out:
#   10 siblings of 61029 = [KA.INIM.MA] IGI GIG.GA.A.KAM₂
#   10 siblings of 61040 = KA.INIM.MA [IGI GIG.GA.A.KAM₂]
#   10 siblings of 61048 = KA.INIM.MA IGI GIG.GA.[KAM₂]
#   10 siblings of 61108 = KA#.[INIM.MA IGI GIG.GA].A#.KAM₂
#   10 siblings of 61185 = [KA.INIM.MA] IGI GIG.GA.A.[KAM₂]
#   10 siblings of 61197 = KA.INIM.MA IGI GIG.GA.A.KAM₂
#   10 siblings of 61205 = KA.[INIM.MA] [IGI GIG.GA.KAM₂]
#   10 siblings of 61213 = [KA.INIM.MA] IGI GIG.[GA.A.KAM₂]
#   10 siblings of 61224 = [KA.INIM.MA IGI] GIG.GA.[KAM₂]
#   10 siblings of 61250 = [KA.INIM].MA IGI GIG.GA.A.KAM₂

# %%
for (ln, paras) in rankedParallels[200:210]:
    print(f"{len(paras):>4} siblings of {T.text(ln).rstrip()}")
# Out:
#    1 siblings of [x x x x x x x ZI₃ ŠE.SA].A ina A GAZI{[sar} x x x x x x x x x x x]
#    1 siblings of [EGIR na]-aṣ-ma-da-te an-na-ti 10 GIN₂ ZA₃.HI.LI ša₂ KA# [x x]
#    1 siblings of [x x x x x x] ZA?#.BA?#.LAM?# 1/3 SILA₃ {u₂}[x x x]
#    1 siblings of [DIŠ NA SAG].KI.DAB.BA TUKU.TUKU [x x x x]
#    1 siblings of [x x x x x x x x x x x x x ŠEŠ₂]-su#-ma# TI
#    1 siblings of [x x x x x x x x x x x TI-šu₂] I₃.GIŠ {šim}GUR₂.GUR₂ ŠEŠ₂-su
#    1 siblings of [x x x x x x x x x x ana TI]-šu₂ I₃.GIŠ {šim}GUR₂.GUR₂ I₃.GIŠ {šim}LI ŠEŠ₂-[su]
#    1 siblings of [x x x x x x x] ŠEŠ₂-su-[ma TI]
#    1 siblings of [x x x x x x x x x] tu#-bal ta-sak₃ ina I₃ HI.HI ŠEŠ₂-MEŠ#-su#-[ma TI]
#    1 siblings of [x x x x x x x tu]-bal ta-sak₃ ina I₃ HI.HI ŠEŠ₂-MEŠ-[su-ma TI]

# %%
for (ln, paras) in rankedParallels[480:490]:
    print(f"{len(paras):>4} siblings of {T.text(ln).rstrip()}")
# Out:
#    1 siblings of BAR {giš}NU#.UR₂#.[MA ...]
#    1 siblings of sah#-le₂#-[e ...]
#    1 siblings of NUMUN {giš}bi-ni SUD₂ ina I₃ u KAŠ NAG SUHUŠ {giš}šu-ši ina I₃ u KAŠ NAG {u₂}IGI.NIŠ SUD₂# [ina KAŠ NAG].MEŠ#
#    1 siblings of [x x] x {šim}GUR₂.GUR₂ {[šim} ...]
#    1 siblings of [KA].INIM.MA MAŠ.TAB.BA.[KE₄]
#    1 siblings of [KA].INIM.MA MAŠ.TAB.[BA.KE₄]
#    1 siblings of [EN₂ ma]-mit GIM šar-ra-qi₂ ina KA₂ pil-ši# [un? ...]
#    1 siblings of DIŠ NA ŠA₃-šu₂ GIG GA {gud}AB₂ KUG.GA I₃.NUN UD.2.KAM₂ [NAG ...]
#    1 siblings of [...] ina KAŠ.SAG NAG
#    1 siblings of [...] x PA {giš}NU.UR₂.MA

# %% [markdown]
# And how many lines have just one correspondence?
#
# We look at the tail of rankedParallels.

# %%
pairs = [(x, list(paras)[0]) for (x, paras) in rankedParallels if len(paras) == 1]
print(f"There are {len(pairs)} exclusively parallel pairs of lines")
# Out:
# There are 304 exclusively parallel pairs of lines

# %% [markdown]
# Why not make an overview of exactly how wide-spread parallel lines are?
#
# We count how many lines have how many parallels.

# %%
parallelCount = collections.Counter()

buckets = (2, 10, 20, 50, 100)

bucketRep = {}
prevBucket = None
for bucket in buckets:
    if prevBucket is None:
        bucketRep[bucket] = f"       n <= {bucket:>3}"
    elif bucket == buckets[-1]:
        bucketRep[bucket] = f"       n >  {bucket:>3}"
    else:
        bucketRep[bucket] = f"{prevBucket:>3} <  n <= {bucket:>3}"
    prevBucket = bucket

for (ln, paras) in rankedParallels:
    clusterSize = len(paras) + 1
    if clusterSize > buckets[-1]:
        theBucket = buckets[-1]
    else:
        for bucket in buckets:
            if clusterSize <= bucket:
                theBucket = bucket
                break
    parallelCount[theBucket] += 1

for (bucket, amount) in sorted(
    parallelCount.items(),
    key=lambda x: (-x[0], x[1]),
):
    print(f"{amount:>4} lines have n sisters where {bucketRep[bucket]}")
# Out:
#   11 lines have n sisters where  10 <  n <=  20
#  187 lines have n sisters where   2 <  n <=  10
#  304 lines have n sisters where        n <=   2

# %% [markdown]
# # Add parallels to the TF dataset
#
# We can add this information to the Oldbabylonian dataset as an *edge feature*.
#
# An edge feature links two nodes and may annotate that link with a value.
#
# For parallels, we link each line to each of its parallel lines and we annotate that link with the similarity between
# the two lines. The similarity is a percentage, and we round it to integer values.
#
# If *n1* is similar to *n2*, then *n2* is similar to *n1*.
# In order to save space, we only add such links once.
#
# We can then use
# [`E.sim.b(node)`](https://annotation.github.io/text-fabric/Api/Features/#edge-features)
# to find all nodes that are parallel to node.

# %%
metaData = {
    "": {
        "name": "Nineveh Medical Encyclopedia Cuneiform",
        "editor": "Cale Johnson et. al.",
        "institute": "Institut für Wissensgeschichte des Altertums",
        "converters": "Cale Johnson, Dirk Roorda",
    },
    "sim": {
        "valueType": "int",
        "edgeValues": True,
        "description": "similarity between lines, as a percentage of the common material wrt the combined material",
    },
}

# %%
simData = {}
for ((f, t), d) in similarity.items():
    simData.setdefault(f, {})[t] = d

# %%
ghBase = os.path.expanduser("~/github")
subdir = "parallels"
path = f"{A.context.org}/{A.context.repo}/{subdir}/tf"
location = f"{ghBase}/{path}"
module = A.version

# %%
TF.save(
    edgeFeatures=dict(sim=simData), metaData=metaData, location=location, module=module
)
# Out:
#   0.00s Exporting 0 node and 1 edge and 0 config features to ~/github/Nino-cunei/ninmed/parallels/tf/0.3:
#    |     0.00s T sim                  to ~/github/Nino-cunei/ninmed/parallels/tf/0.3
#   0.00s Exported 0 node features and 1 edge features and 0 config features to ~/github/Nino-cunei/ninmed/parallels/tf/0.3
# True

# %% [markdown]
# # Turn the parallels feature into a module
#
# The new `sim` feature is a big data feature. You do not want to load it all the time.
#
# Here we show how to turn it into a module, so that users can easily load it in a Jupyter notebook or in the TF browser.

# %%
# %%bash
# text-fabric-zip 'Nino-cunei/ninmed/parallels/tf'
# Out:
# This is a TF dataset
# Create release data for Nino-cunei/ninmed/parallels/tf
# Found 2 versions
# zip files end up in ~/Downloads/Nino-cunei-release/ninmed
# zipping Nino-cunei/ninmed          0.2 with   1 features ==> parallels-tf-0.2.zip
# zipping Nino-cunei/ninmed          0.3 with   1 features ==> parallels-tf-0.3.zip

# %% [markdown]
# I have added this file to a new release of this Github repo.

# %% [markdown]
# # Use the parallels module
#
# See tutorial similarLines.
